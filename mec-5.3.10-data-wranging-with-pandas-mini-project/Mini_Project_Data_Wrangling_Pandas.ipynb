# %% [markdown]
# # Mini-Project: Data Wrangling and Transformation with Pandas
#
# Working with tabular data is a necessity for anyone with enterprises having a majority of their data in relational databases and flat files. This mini-project is adopted from the excellent tutorial on pandas by Brandon Rhodes which you have watched earlier in the Data Wrangling Unit. In this mini-project, we will be looking at some interesting data based on movie data from the IMDB.
#
# This assignment should help you reinforce the concepts you learnt in the curriculum for Data Wrangling and sharpen your skills in using Pandas. Good Luck!

# %% [markdown]
# ### Please make sure you have one of the more recent versions of Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.4.2'

# %% [markdown]
# ## Taking a look at the Movies dataset
# This data shows the movies based on their title and the year of release

# %%
movies = pd.read_csv('titles.csv')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244914 entries, 0 to 244913
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   title   244914 non-null  object
#  1   year    244914 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.7+ MB

# %%
movies.head()
# Out:
#                                           title  year
# 0                        The Ticket to the Life  2009
# 1  Parallel Worlds: A New Rock Music Experience  2016
# 2                     Morita - La hija de Jesus  2008
# 3                                           Gun  2017
# 4                        Love or Nothing at All  2014

# %% [markdown]
# ## Taking a look at the Cast dataset
#
# This data shows the cast (actors, actresses, supporting roles) for each movie
#
# - The attribute `n` basically tells the importance of the cast role, lower the number, more important the role.
# - Supporting cast usually don't have any value for `n`

# %%
cast = pd.read_csv('cast.csv.zip')
cast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786176 entries, 0 to 3786175
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   title      object
#  1   year       int64
#  2   name       object
#  3   type       object
#  4   character  object
#  5   n          float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 173.3+ MB

# %%
cast.head(10)
# Out:
#                                                title  year  \
# 0                                     Closet Monster  2015
# 1                                    Suuri illusioni  1985
# 2                                Battle of the Sexes  2017
# 3                               Secret in Their Eyes  2015
# 4                                         Steve Jobs  2015
# 5                             Straight Outta Compton  2015
# 6                             Straight Outta Compton  2015
# 7                                     For Thy Love 2  2009
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                       Desire (III)  2014
#
#                         name   type                               character  \
# 0                   Buffy #1  actor                                 Buffy 4
# 1                     Homo $  actor                                  Guests
# 2                    $hutter  actor                         Bobby Riggs Fan
# 3                    $hutter  actor                         2002 Dodger Fan
# 4                    $hutter  actor                 1988 Opera House Patron
# 5                    $hutter  actor                             Club Patron
# 6                    $hutter  actor                                 Dopeman
# 7               Bee Moe $lim  actor                                  Thug 1
# 8  Jori ' Danilo' Jurado Jr.  actor                           Jaime (young)
# 9           Syaiful 'Ariffin  actor  Actor Playing Eteocles from 'Antigone'
#
#       n
# 0  31.0
# 1  22.0
# 2  10.0
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   9.0
# 9   NaN

# %% [markdown]
# ## Taking a look at the Release dataset
#
# This data shows details of when each movie was release in each country with the release date

# %%
release_dates = pd.read_csv('release_dates.csv', parse_dates=['date'], infer_datetime_format=True)
release_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479488 entries, 0 to 479487
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   title    479488 non-null  object
#  1   year     479488 non-null  int64
#  2   country  479488 non-null  object
#  3   date     479488 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 14.6+ MB

# %%
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %% [markdown]
# # Section I - Basic Querying, Filtering and Transformations

# %% [markdown]
# ### What is the total number of movies?

# %%
len(movies)
# Out:
# 244914

# %% [markdown]
# ### List all Batman movies ever made

# %%
batman_df = movies[movies.title == 'Batman']
print('Total Batman Movies:', len(batman_df))
batman_df
# Out:
# Total Batman Movies: 2
#          title  year
# 52734   Batman  1943
# 150621  Batman  1989

# %%
# This seems like a better way to do this (below) than the cell above.

batman_df2 = movies[movies.title.str.contains('Batman', regex=False)]
print('Batman Movies: ', len(batman_df2['title']))
batman_df2.sort_values('year', ascending=False)
# Out:
# Batman Movies:  35
#                                               title  year
# 31711   Scooby-Doo & Batman: the Brave and the Bold  2018
# 41881                   Batman the Rise of Red Hood  2018
# 119009             Batman V Superman: League at War  2018
# 99828                               Batman Unveiled  2018
# 71103                                  Batman Ninja  2018
# 65209                        Batman: Master of Fear  2017
# 179580                Batman the Dawn of the Knight  2017
# 179004                        The LEGO Batman Movie  2017
# 16813                               Batman: Anarchy  2016
# 216651                     Batman: The Killing Joke  2016
# 206788           B@: It's a Wonderful Life, Batman!  2016
# 110458                      B@ (Batman Parody Film)  2016
# 241878           Batman v Superman: Dawn of Justice  2016
# 43484         Batman: Return of the Caped Crusaders  2016
# 61569                              Batman: Crusader  2014
# 56029                  Batman Beyond: Rising Knight  2014
# 51811                               Batman Revealed  2012
# 78469                     Batman: The Final Victory  2010
# 31674                                 Batman Untold  2010
# 116892                               Batman Reboots  2010
# 208220                                Batman Begins  2005
# 46333                                Batman & Robin  1997
# 30236                                Batman Forever  1995
# 63366                  Batman: Mask of the Phantasm  1993
# 156755                               Batman Returns  1992
# 156239                        Alyas Batman en Robin  1991
# 150621                                       Batman  1989
# 168504                        Fight! Batman, Fight!  1973
# 56159                         Batman Fights Dracula  1967
# 161527                            Batman: The Movie  1966
# 68364                                  James Batman  1966
# 84327                         Alyas Batman at Robin  1965
# 161439                               Batman Dracula  1964
# 100056                             Batman and Robin  1949
# 52734                                        Batman  1943

# %% [markdown]
# ### List all Batman movies ever made - the right approach

# %%
batman_df = movies[movies.title.str.contains('Batman', case=False)]
print('Total Batman Movies:', len(batman_df))
print('ignores case... smart')
batman_df
# Out:
# Total Batman Movies: 35
# ignores case... smart
#                                               title  year
# 16813                               Batman: Anarchy  2016
# 30236                                Batman Forever  1995
# 31674                                 Batman Untold  2010
# 31711   Scooby-Doo & Batman: the Brave and the Bold  2018
# 41881                   Batman the Rise of Red Hood  2018
# 43484         Batman: Return of the Caped Crusaders  2016
# 46333                                Batman & Robin  1997
# 51811                               Batman Revealed  2012
# 52734                                        Batman  1943
# 56029                  Batman Beyond: Rising Knight  2014
# 56159                         Batman Fights Dracula  1967
# 61569                              Batman: Crusader  2014
# 63366                  Batman: Mask of the Phantasm  1993
# 65209                        Batman: Master of Fear  2017
# 68364                                  James Batman  1966
# 71103                                  Batman Ninja  2018
# 78469                     Batman: The Final Victory  2010
# 84327                         Alyas Batman at Robin  1965
# 99828                               Batman Unveiled  2018
# 100056                             Batman and Robin  1949
# 110458                      B@ (Batman Parody Film)  2016
# 116892                               Batman Reboots  2010
# 119009             Batman V Superman: League at War  2018
# 150621                                       Batman  1989
# 156239                        Alyas Batman en Robin  1991
# 156755                               Batman Returns  1992
# 161439                               Batman Dracula  1964
# 161527                            Batman: The Movie  1966
# 168504                        Fight! Batman, Fight!  1973
# 179004                        The LEGO Batman Movie  2017
# 179580                Batman the Dawn of the Knight  2017
# 206788           B@: It's a Wonderful Life, Batman!  2016
# 208220                                Batman Begins  2005
# 216651                     Batman: The Killing Joke  2016
# 241878           Batman v Superman: Dawn of Justice  2016

# %% [markdown]
# ### Display the top 15 Batman movies in the order they were released

# %%
batman_df.sort_values(by=['year'], ascending=True).iloc[:15]
# Out:
#                                title  year
# 52734                         Batman  1943
# 100056              Batman and Robin  1949
# 161439                Batman Dracula  1964
# 84327          Alyas Batman at Robin  1965
# 68364                   James Batman  1966
# 161527             Batman: The Movie  1966
# 56159          Batman Fights Dracula  1967
# 168504         Fight! Batman, Fight!  1973
# 150621                        Batman  1989
# 156239         Alyas Batman en Robin  1991
# 156755                Batman Returns  1992
# 63366   Batman: Mask of the Phantasm  1993
# 30236                 Batman Forever  1995
# 46333                 Batman & Robin  1997
# 208220                 Batman Begins  2005

# %% [markdown]
# ### Section I - Q1 : List all the 'Harry Potter' movies from the most recent to the earliest

# %%
hp_df = movies[movies['title'].str.contains('Harry Potter', case=False, regex=False)]
hp_df.sort_values('year', ascending=False)
# Out:
#                                                title  year
# 143147  Harry Potter and the Deathly Hallows: Part 2  2011
# 152831  Harry Potter and the Deathly Hallows: Part 1  2010
# 109213        Harry Potter and the Half-Blood Prince  2009
# 50581      Harry Potter and the Order of the Phoenix  2007
# 187926           Harry Potter and the Goblet of Fire  2005
# 61957       Harry Potter and the Prisoner of Azkaban  2004
# 82791        Harry Potter and the Chamber of Secrets  2002
# 223087         Harry Potter and the Sorcerer's Stone  2001

# %% [markdown]
# ### How many movies were made in the year 2017?

# %%
len(movies[movies.year == 2017])
# Out:
# 11474

# %% [markdown]
# ### Section I - Q2 : How many movies were made in the year 2015?

# %%
len(movies[movies.year == 2015])
# Out:
# 8702

# %% [markdown]
# ### Section I - Q3 : How many movies were made from 2000 till 2018?
# - You can chain multiple conditions using OR (`|`) as well as AND (`&`) depending on the condition

# %%
len(movies[(movies.year >= 2000) & (movies.year < 2018)])
# Out:
# 106029

# %% [markdown]
# ### Section I - Q4: How many movies are titled "Hamlet"?

# %%
len(movies[movies.title == 'Hamlet'])
# Out:
# 20

# %% [markdown]
# ### Section I - Q5: List all movies titled "Hamlet"
# - The movies should only have been released on or after the year 2000
# - Display the movies based on the year they were released (earliest to most recent)

# %%
hamlet2000_df = movies[(movies.title == 'Hamlet') & (movies.year >= 2000)]
hamlet2000_df.sort_values('year', ascending=True)
# Out:
#          title  year
# 55639   Hamlet  2000
# 1931    Hamlet  2009
# 227953  Hamlet  2011
# 178290  Hamlet  2014
# 186137  Hamlet  2015
# 191940  Hamlet  2016
# 244747  Hamlet  2017

# %% [markdown]
# ### Section I - Q6: How many roles in the movie "Inception" are of the supporting cast (extra credits)
# - supporting cast are NOT ranked by an "n" value (NaN)
# - check for how to filter based on nulls

# %%
len(cast[cast.title.str.contains('inception', case=False)].n.isna())
# Out:
# 87

# %% [markdown]
# ### Section I - Q7: How many roles in the movie "Inception" are of the main cast
# - main cast always have an 'n' value

# %%
cast[cast.title.str.contains('inception', case=False)].n.count()
# Out:
# 51

# %% [markdown]
# ### Section I - Q8: Show the top ten cast (actors\actresses) in the movie "Inception"
# - main cast always have an 'n' value
# - remember to sort!

# %%
cast[cast.title.str.contains('inception', case=False)].sort_values('n', ascending=True).head(10)
# Out:
#              title  year                  name     type        character     n
# 590576   Inception  2010     Leonardo DiCaprio    actor             Cobb   1.0
# 859993   Inception  2010  Joseph Gordon-Levitt    actor           Arthur   2.0
# 3387147  Inception  2010            Ellen Page  actress          Ariadne   3.0
# 940923   Inception  2010             Tom Hardy    actor            Eames   4.0
# 2406531  Inception  2010          Ken Watanabe    actor            Saito   5.0
# 1876301  Inception  2010            Dileep Rao    actor            Yusuf   6.0
# 1615709  Inception  2010        Cillian Murphy    actor   Robert Fischer   7.0
# 183937   Inception  2010          Tom Berenger    actor         Browning   8.0
# 2765969  Inception  2010      Marion Cotillard  actress              Mal   9.0
# 1826027  Inception  2010    Pete Postlethwaite    actor  Maurice Fischer  10.0

# %% [markdown]
# ### Section I - Q9:
#
# (A) List all movies where there was a character 'Albus Dumbledore'
#
# (B) Now modify the above to show only the actors who played the character 'Albus Dumbledore'
# - For Part (B) remember the same actor might play the same role in multiple movies

# %%
list(cast[cast.character.str.contains('Albus Dumbledore')].title)
# Out:
# ['Epic Movie',
#  'Harry Potter and the Deathly Hallows: Part 1',
#  'Harry Potter and the Deathly Hallows: Part 2',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Half-Blood Prince',
#  'Harry Potter and the Order of the Phoenix',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Harry Potter and the Chamber of Secrets',
#  "Harry Potter and the Sorcerer's Stone",
#  'Ultimate Hero Project',
#  'Harry Potter and the Deathly Hallows: Part 1',
#  'Potter']

# %%
list(cast[cast.character.str.contains('Albus Dumbledore')].name.unique())
# Out:
# ['Dane Farwell',
#  'Michael Gambon',
#  'Richard Harris',
#  "George (X) O'Connor",
#  'Toby Regbo',
#  'Timothy Tedmanson']

# %% [markdown]
# ### Section I - Q10:
#
# (A) How many roles has 'Keanu Reeves' played throughout his career?
#
# (B) List the leading roles that 'Keanu Reeves' played on or after 1999 in order by year.

# %%
len(cast[cast.name.str.contains('Keanu Reeves')].character)
# Out:
# 62

# %%
cast[cast.name.str.contains('Keanu Reeves') 
     & (cast['n'] == 1.0) 
     & (cast.year >= 1999)].sort_values('year')
# Out:
#                                  title  year          name   type  \
# 1892390                     The Matrix  1999  Keanu Reeves  actor
# 1892397               The Replacements  2000  Keanu Reeves  actor
# 1892358                      Hard Ball  2001  Keanu Reeves  actor
# 1892383                 Sweet November  2001  Keanu Reeves  actor
# 1892348                    Constantine  2005  Keanu Reeves  actor
# 1892388                 The Lake House  2006  Keanu Reeves  actor
# 1892382                   Street Kings  2008  Keanu Reeves  actor
# 1892385  The Day the Earth Stood Still  2008  Keanu Reeves  actor
# 1892359                  Henry's Crime  2010  Keanu Reeves  actor
# 1892342                       47 Ronin  2013  Keanu Reeves  actor
# 1892361                      John Wick  2014  Keanu Reeves  actor
# 1892366                    Knock Knock  2015  Keanu Reeves  actor
# 1892399                The Whole Truth  2016  Keanu Reeves  actor
# 1892362           John Wick: Chapter 2  2017  Keanu Reeves  actor
# 1892378                        Siberia  2018  Keanu Reeves  actor
#
#                     character    n
# 1892390                   Neo  1.0
# 1892397           Shane Falco  1.0
# 1892358         Conor O'Neill  1.0
# 1892383           Nelson Moss  1.0
# 1892348      John Constantine  1.0
# 1892388            Alex Wyler  1.0
# 1892382  Detective Tom Ludlow  1.0
# 1892385                Klaatu  1.0
# 1892359           Henry Torne  1.0
# 1892342                   Kai  1.0
# 1892361             John Wick  1.0
# 1892366                  Evan  1.0
# 1892399                Ramsey  1.0
# 1892362             John Wick  1.0
# 1892378            Lucas Hill  1.0

# %% [markdown]
# ### Section I - Q11:
#
# (A) List the total number of actor and actress roles available from 1950 - 1960
#
# (B) List the total number of actor and actress roles available from 2007 - 2017

# %%
num_actor1960 = len(cast[(cast.year >= 1950) 
                         & (cast.year <= 1960) 
                         & (cast.type == 'actor')])
num_actress1960 = len(cast[(cast.year >= 1950) 
                         & (cast.year <= 1960) 
                         & (cast.type == 'actress')])

print('actor roles available 1950-1960 (inclusive): ', num_actor1960)
print('actress roles available 1950-1960 (inclusive): ', num_actress1960)
# Out:
# actor roles available 1950-1960 (inclusive):  171302
# actress roles available 1950-1960 (inclusive):  63333

# %%
num_actor2017 = len(cast[(cast.year >= 2007) 
                         & (cast.year <= 2017) 
                         & (cast.type == 'actor')])
num_actress2017 = len(cast[(cast.year >= 2007) 
                         & (cast.year <= 2017) 
                         & (cast.type == 'actress')])

print('actor roles available 2007-2017 (inclusive): ', num_actor2017)
print('actress roles available 2007-2017 (inclusive): ', num_actress2017)
# Out:
# actor roles available 2007-2017 (inclusive):  922782
# actress roles available 2007-2017 (inclusive):  529631

# %% [markdown]
# ### Section I - Q12:
#
# (A) List the total number of leading roles available from 2000 to present
#
# (B) List the total number of non-leading roles available from 2000 - present (exclude support cast)
#
# (C) List the total number of support\extra-credit roles available from 2000 - present

# %%
# A. number of leading roles from 2000 to present
len(cast[(cast.n == 1.0) & (cast.year >= 2000)])
# Out:
# 60568

# %%
# B. number of non-leading roles from 2000 - present (excluding support)
cast[(cast.n != 1.0) & (cast.year >= 2000)].n.count()
# Out:
# 1001710

# %%
# C.number of support/extra roles from 2000 - present
cast[(cast.n != 1.0) & (cast.year >= 2000)].n.isna().sum()
# Out:
# 887484

# %% [markdown]
# # Section II - Aggregations, Transformations and Visualizations

# %% [markdown]
# ## What are the top ten most common movie names of all time?

# %%
top_ten = movies.title.value_counts()[:10]
top_ten
# Out:
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# Maya                    12
# Temptation              12
# The Outsider            12
# Freedom                 11
# The Three Musketeers    11
# Honeymoon               11
# Othello                 11
# Name: title, dtype: int64

# %% [markdown]
# ### Plot the top ten common movie names of all time

# %%
top_ten.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Section II - Q1:  Which years in the 2000s saw the most movies released? (Show top 3)

# %%
movies3 = movies.year.value_counts()[:3]

# %%
movies3.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Section II - Q2: # Plot the total number of films released per-decade (1890, 1900, 1910,....)
# - Hint: Dividing the year and multiplying with a number might give you the decade the year falls into!
# - You might need to sort before plotting

# %%
print('max year:', movies.year.max())
print('min year:', movies.year.min())
print('count year > 2022:', movies[movies.year > 2022].year.count())
print('odd...')
# Out:
# max year: 2115
# min year: 1894
# count year > 2022: 14
# odd...

# %%
movies[movies.year == 2115]
# Out:
#            title  year
# 78061  100 Years  2115

# %%
# make bins
left_bins = pd.Series(range(
                    ((movies.year.min()//10)*10),
                    (((movies.year.max()+10)//10)*10),
                    10))
right_bins = bins.map(lambda x: x+9)

bin_intervals = pd.IntervalIndex.from_arrays(left_bins, right_bins, closed='both')
bin_intervals
# Out:
# IntervalIndex([[1890, 1899], [1900, 1909], [1910, 1919], [1920, 1929], [1930, 1939] ... [2070, 2079], [2080, 2089], [2090, 2099], [2100, 2109], [2110, 2119]], dtype='interval[int64, both]')

# %%
# ripping from Nickil Maveli on Stack Overflow:
# https://stackoverflow.com/questions/43005462/pandas-bar-plot-with-binned-range

# Plot

out = pd.cut(movies.year, bins=bin_intervals, include_lowest=True)
ax = out.value_counts(sort=False).plot.bar(color='#c871eb', figsize=(12,4))
ax.set_xticklabels([str(i) for i in bins], rotation=60, color='white')
plt.yticks(color = 'white')
plt.grid(visible=True, alpha=0.2)
plt.title('Total Number of Films Released per Decade 1890-2120', color='white')
plt.show()

# %%
# pd.cut() was a fun method... and useful!!

out
# Out:
# 0         [2000, 2009]
# 1         [2010, 2019]
# 2         [2000, 2009]
# 3         [2010, 2019]
# 4         [2010, 2019]
#               ...
# 244909    [1990, 1999]
# 244910    [1980, 1989]
# 244911    [1970, 1979]
# 244912    [1950, 1959]
# 244913    [1990, 1999]
# Name: year, Length: 244914, dtype: category
# Categories (23, interval[int64, both]): [[1890, 1899] < [1900, 1909] < [1910, 1919] < [1920, 1929] ... [2080, 2089] < [2090, 2099] < [2100, 2109] < [2110, 2119]]

# %%
# verify the 2010-2020... seems fishy
movies[(movies.year >= 2010) & (movies.year < 2020)].year.count()
# Out:
# 75733

# %%
# verify the 2020-2030 bin
movies[(movies.year >= 2020) & (movies.year <= 2030)].year.count()
# Out:
# 285

# %% [markdown]
# ### Section II - Q3:
#
# (A) What are the top 10 most common character names in movie history?
#
# (B) Who are the top 10 people most often credited as "Herself" in movie history?
#
# (C) Who are the top 10 people most often credited as "Himself" in movie history?

# %%
# A. 10 most common character names
cast.character.value_counts().head(10)
# Out:
# Himself        20746
# Dancer         12477
# Extra          11948
# Reporter        8434
# Student         7773
# Doctor          7669
# Party Guest     7245
# Policeman       7029
# Nurse           6999
# Bartender       6802
# Name: character, dtype: int64

# %%
# B. top 10 credited as "Herself"
cast[cast.character.str.contains('Herself', case=False)].name.value_counts().head(10)
# Out:
# Queen Elizabeth II                  18
# Jacqueline Kennedy                  12
# Margaret Thatcher                   10
# Joyce Brothers                      10
# Hillary Clinton                      9
# Mar?a Luisa (V) Mart?n               9
# Luisa Horga                          9
# Pat Nixon                            8
# Caroline Kennedy                     7
# Queen Elizabeth the Queen Mother     7
# Name: name, dtype: int64

# %%
# C. top 10 credited as "Himself"
cast[cast.character.str.contains('Himself', case=False)].name.value_counts().head(10)
# Out:
# Adolf Hitler             115
# Richard Nixon             54
# John F. Kennedy           49
# Ronald Reagan             46
# George W. Bush            28
# Winston Churchill         28
# Martin Luther King        26
# Benito Mussolini          26
# Franklin D. Roosevelt     25
# Bill Clinton              23
# Name: name, dtype: int64

# %% [markdown]
# That's pretty weird... third reich movies/propoganda? let's find out.

# %%
# What is Hitler up to in all these movies

ah_df = cast[cast.name == 'Adolf Hitler']
pd.set_option('display.max_rows', 500)
ah_df.sort_values('year', ascending=False)
# Out:
#                                               title  year          name  \
# 1005074                                      Django  2017  Adolf Hitler
# 1005055                                  Anthropoid  2016  Adolf Hitler
# 1005145                     The Man from U.N.C.L.E.  2015  Adolf Hitler
# 1005166                   What We Do in the Shadows  2014  Adolf Hitler
# 1005152                         The Sound of Spying  2014  Adolf Hitler
# 1005142                          The Imitation Game  2014  Adolf Hitler
# 1005066             Dalla Corsica alla linea gotica  2013  Adolf Hitler
# 1005130                              The Book Thief  2013  Adolf Hitler
# 1005163                               Untitled (IV)  2012  Adolf Hitler
# 1005058                 BloodRayne: The Third Reich  2011  Adolf Hitler
# 1005151                               The Rum Diary  2011  Adolf Hitler
# 1005098                                  L'aviatore  2011  Adolf Hitler
# 1005143                           The King's Speech  2010  Adolf Hitler
# 1005101                                    La rafle  2010  Adolf Hitler
# 1005086                                   Hired Gun  2009  Adolf Hitler
# 1005158                                  Town Creek  2009  Adolf Hitler
# 1005057                                  Berlin '36  2009  Adolf Hitler
# 1005061              Con la muerte en los 2 tacones  2009  Adolf Hitler
# 1005070                                    Defiance  2008  Adolf Hitler
# 1005140                           The Good Shepherd  2006  Adolf Hitler
# 1005141                              The Great Raid  2005  Adolf Hitler
# 1005111                      Mrs Henderson Presents  2005  Adolf Hitler
# 1005162                                   Unkenrufe  2005  Adolf Hitler
# 1005093                              In Enemy Hands  2004  Adolf Hitler
# 1005123                                    Sideways  2004  Adolf Hitler
# 1005075                                    Elephant  2003  Adolf Hitler
# 1005095                          Jigureul jikyeora!  2003  Adolf Hitler
# 1005089            Hitler and Stalin: Roots of Evil  2002  Adolf Hitler
# 1005119                                Pearl Harbor  2001  Adolf Hitler
# 1005076                                      Enigma  2001  Adolf Hitler
# 1005127                                Taking Sides  2001  Adolf Hitler
# 1005118                    One of the Hollywood Ten  2000  Adolf Hitler
# 1005094                              Jakob the Liar  1999  Adolf Hitler
# 1005126                                    Sunshine  1999  Adolf Hitler
# 1005084  Gloomy Sunday - Ein Lied von Liebe und Tod  1999  Adolf Hitler
# 1005063                                     Contact  1997  Adolf Hitler
# 1005110                                Mother Night  1996  Adolf Hitler
# 1005132           The Disappearance of Garcia Lorca  1996  Adolf Hitler
# 1005135                            The Empty Mirror  1996  Adolf Hitler
# 1005115                                 Nostradamus  1994  Adolf Hitler
# 1005060                                     Chaplin  1992  Adolf Hitler
# 1005133                                   The Doors  1991  Adolf Hitler
# 1005105                                 Lune froide  1991  Adolf Hitler
# 1005150                               The Rocketeer  1991  Adolf Hitler
# 1005077                                      Father  1990  Adolf Hitler
# 1005081         Georg Elser - Einer aus Deutschland  1989  Adolf Hitler
# 1005159                       Triumph of the Spirit  1989  Adolf Hitler
# 1005099                     La bottega dell'orefice  1988  Adolf Hitler
# 1005064                                    Critters  1986  Adolf Hitler
# 1005091                                Idi i smotri  1985  Adolf Hitler
# 1005169                             Yo amo a Hitler  1984  Adolf Hitler
# 1005148            The Return of Captain Invincible  1983  Adolf Hitler
# 1005170                                       Zelig  1983  Adolf Hitler
# 1005067            De camisa vieja a chaqueta nueva  1982  Adolf Hitler
# 1005120                                Pedon merkki  1981  Adolf Hitler
# 1005146                    The Man Who Saw Tomorrow  1981  Adolf Hitler
# 1005068                                  Death Ship  1980  Adolf Hitler
# 1005079                        From Hell to Victory  1979  Adolf Hitler
# 1005072                            Die Blechtrommel  1979  Adolf Hitler
# 1005096                                   Kainuu 39  1979  Adolf Hitler
# 1005114                          Nightmare in Blood  1977  Adolf Hitler
# 1005147                  The Other Side of Midnight  1977  Adolf Hitler
# 1005065                               Cross of Iron  1977  Adolf Hitler
# 1005103               Le lunghe notti della Gestapo  1977  Adolf Hitler
# 1005052                            A Bridge Too Far  1977  Adolf Hitler
# 1005160                    Una giornata particolare  1977  Adolf Hitler
# 1005168                                     Wizards  1977  Adolf Hitler
# 1005134                        The Eagle Has Landed  1976  Adolf Hitler
# 1005167                          Wienfilm 1896-1976  1976  Adolf Hitler
# 1005129                           The Black Gestapo  1975  Adolf Hitler
# 1005112                       Mussolini ultimo atto  1974  Adolf Hitler
# 1005128         The Apprenticeship of Duddy Kravitz  1974  Adolf Hitler
# 1005104                                    Le train  1973  Adolf Hitler
# 1005083                                    Gli eroi  1973  Adolf Hitler
# 1005053                          A Clockwork Orange  1971  Adolf Hitler
# 1005121                              Plasticni Isus  1971  Adolf Hitler
# 1005161               Und Jimmy ging zum Regenbogen  1971  Adolf Hitler
# 1005054  And Now for Something Completely Different  1971  Adolf Hitler
# 1005092               Il giardino dei Finzi Contini  1970  Adolf Hitler
# 1005085                        Hell's Bloody Devils  1970  Adolf Hitler
# 1005125                       Storm Troopers U.S.A.  1969  Adolf Hitler
# 1005073                         Dieu a choisi Paris  1969  Adolf Hitler
# 1005136                    The Extraordinary Seaman  1969  Adolf Hitler
# 1005156                       Till Death Us Do Part  1968  Adolf Hitler
# 1005100                          La feldmarescialla  1967  Adolf Hitler
# 1005051                                    36 Hours  1964  Adolf Hitler
# 1005102                    La vergine di Norimberga  1963  Adolf Hitler
# 1005131                                The Cardinal  1963  Adolf Hitler
# 1005153                                 The Victors  1963  Adolf Hitler
# 1005087                                      Hitler  1962  Adolf Hitler
# 1005124                          Sink the Bismarck!  1960  Adolf Hitler
# 1005165                           Wernher von Braun  1960  Adolf Hitler
# 1005071                      Der Rest ist Schweigen  1959  Adolf Hitler
# 1005080               Geheimaktion Schwarze Kapelle  1959  Adolf Hitler
# 1005090                 Hunde, wollt ihr ewig leben  1959  Adolf Hitler
# 1005164                                   Verboten!  1959  Adolf Hitler
# 1005059                                     Canaris  1954  Adolf Hitler
# 1005116                        Once a Jolly Swagman  1949  Adolf Hitler
# 1005097                       Kampen om tungtvannet  1948  Adolf Hitler
# 1005082                          Germania anno zero  1948  Adolf Hitler
# 1005109                            Monsieur Verdoux  1947  Adolf Hitler
# 1005157                     Tonight and Every Night  1945  Adolf Hitler
# 1005069                     December 7th: The Movie  1943  Adolf Hitler
# 1005108                           Mission to Moscow  1943  Adolf Hitler
# 1005138                            The Flemish Farm  1943  Adolf Hitler
# 1005107                          Miss V from Moscow  1942  Adolf Hitler
# 1005137                        The First of the Few  1942  Adolf Hitler
# 1005117                       Once Upon a Honeymoon  1942  Adolf Hitler
# 1005155                                Thunder Rock  1942  Adolf Hitler
# 1005122                           Reunion in France  1942  Adolf Hitler
# 1005078                               Freedom Radio  1941  Adolf Hitler
# 1005106                                    Man Hunt  1941  Adolf Hitler
# 1005113                       Night Train to Munich  1940  Adolf Hitler
# 1005056                                 Band Waggon  1940  Adolf Hitler
# 1005062                   Confessions of a Nazi Spy  1939  Adolf Hitler
# 1005149                        The Roaring Twenties  1939  Adolf Hitler
# 1005088                    Hitler - Beast of Berlin  1939  Adolf Hitler
# 1005144                          The Lion Has Wings  1939  Adolf Hitler
# 1005139                           The Four Just Men  1939  Adolf Hitler
# 1005154                          The World Moves On  1934  Adolf Hitler
#
#           type                                      character    n
# 1005074  actor                                        Himself  NaN
# 1005055  actor                                        Himself  NaN
# 1005145  actor                                        Himself  NaN
# 1005166  actor                                        Himself  NaN
# 1005152  actor                                        Himself  NaN
# 1005142  actor                                        Himself  NaN
# 1005066  actor                                        Himself  NaN
# 1005130  actor                                        Himself  NaN
# 1005163  actor                                        Himself  NaN
# 1005058  actor                                        Himself  NaN
# 1005151  actor                                        Himself  NaN
# 1005098  actor                                        Himself  NaN
# 1005143  actor                                        Himself  NaN
# 1005101  actor                                        Himself  NaN
# 1005086  actor                                        Himself  NaN
# 1005158  actor                                        Himself  NaN
# 1005057  actor                                        Himself  NaN
# 1005061  actor                                        Himself  NaN
# 1005070  actor                                        Himself  NaN
# 1005140  actor                                        Himself  NaN
# 1005141  actor                                        Himself  NaN
# 1005111  actor                                        Himself  NaN
# 1005162  actor                                        Himself  NaN
# 1005093  actor                                        Himself  NaN
# 1005123  actor                                        Himself  NaN
# 1005075  actor                                        Himself  NaN
# 1005095  actor                                        Himself  NaN
# 1005089  actor                                        Himself  NaN
# 1005119  actor                                        Himself  NaN
# 1005076  actor                                        Himself  NaN
# 1005127  actor                                        Himself  NaN
# 1005118  actor                                        Himself  NaN
# 1005094  actor     Himself - 'Behind Us Comes Germany' Speech  NaN
# 1005126  actor  Himself - at the 1936 Olympic Games in Berlin  NaN
# 1005084  actor                                        Himself  NaN
# 1005063  actor                                        Himself  NaN
# 1005110  actor     Himself - 'Behind Us Comes Germany' Speech  NaN
# 1005132  actor     Himself - Reviews Honour Guard with Franco  NaN
# 1005135  actor                                        Himself  NaN
# 1005115  actor                                        Himself  NaN
# 1005060  actor                                        Himself  NaN
# 1005133  actor                            Himself - in Speech  NaN
# 1005105  actor                                        Himself  NaN
# 1005150  actor                                        Himself  NaN
# 1005077  actor                                        Himself  NaN
# 1005081  actor                                        Himself  NaN
# 1005159  actor                                        Himself  NaN
# 1005099  actor                 Himself - Walks with Mussolini  NaN
# 1005064  actor                                        Himself  NaN
# 1005091  actor                                        Himself  NaN
# 1005169  actor                                        Himself  NaN
# 1005148  actor                                        Himself  NaN
# 1005170  actor                                        Himself  NaN
# 1005067  actor                                        Himself  NaN
# 1005120  actor                                        Himself  NaN
# 1005146  actor                  Himself - Speech, from T.d.W.  NaN
# 1005068  actor                                        Himself  NaN
# 1005079  actor                                        Himself  NaN
# 1005072  actor                                        Himself  NaN
# 1005096  actor                                        Himself  3.0
# 1005114  actor                                        Himself  NaN
# 1005147  actor                                        Himself  NaN
# 1005065  actor                                        Himself  NaN
# 1005103  actor                                        Himself  NaN
# 1005052  actor                       Himself - Salutes Parade  NaN
# 1005160  actor                                        Himself  NaN
# 1005168  actor                                        Himself  NaN
# 1005134  actor        Himself - Greets Mussolini After Rescue  NaN
# 1005167  actor                                        Himself  NaN
# 1005129  actor                                        Himself  NaN
# 1005112  actor                Himself - In Car with Mussolini  NaN
# 1005128  actor                                        Himself  NaN
# 1005104  actor                                        Himself  NaN
# 1005083  actor                                        Himself  NaN
# 1005053  actor                                        Himself  NaN
# 1005121  actor                                        Himself  NaN
# 1005161  actor                                        Himself  NaN
# 1005054  actor           Himself - Speech to RAD, from T.d.W.  NaN
# 1005092  actor                    Himself - Acknowledges Hess  NaN
# 1005085  actor                                        Himself  NaN
# 1005125  actor                                        Himself  NaN
# 1005073  actor                                        Asshole  NaN
# 1005136  actor                                        Himself  NaN
# 1005156  actor                                        Himself  NaN
# 1005100  actor                                        Himself  NaN
# 1005051  actor                          Himself - in Newsreel  NaN
# 1005102  actor                                        Himself  NaN
# 1005131  actor                                        Himself  NaN
# 1005153  actor                                        Himself  NaN
# 1005087  actor                                        Himself  NaN
# 1005124  actor              Himself - at Launch of 'Bismarck'  NaN
# 1005165  actor                                        Himself  NaN
# 1005071  actor                                        Himself  NaN
# 1005080  actor                                        Himself  NaN
# 1005090  actor                                        Himself  NaN
# 1005164  actor                                        Himself  NaN
# 1005059  actor                                        Himself  NaN
# 1005116  actor                                        Himself  NaN
# 1005097  actor                           Himself - Der F?hrer  NaN
# 1005082  actor                                        Himself  NaN
# 1005109  actor            Adolph Hitler: Clips from newsreels  NaN
# 1005157  actor                                         Hitler  NaN
# 1005069  actor                                        Himself  NaN
# 1005108  actor                                  Adolph Hitler  NaN
# 1005138  actor                                        Himself  NaN
# 1005107  actor                                        Himself  NaN
# 1005137  actor                                        Himself  NaN
# 1005117  actor                                        Himself  NaN
# 1005155  actor                                        Himself  NaN
# 1005122  actor                                        Himself  NaN
# 1005078  actor                                        Himself  NaN
# 1005106  actor                           Himself (in montage)  NaN
# 1005113  actor                                        Himself  NaN
# 1005056  actor                                        Himself  NaN
# 1005062  actor                                        Himself  NaN
# 1005149  actor                                        Himself  NaN
# 1005088  actor                                   Adolf Hitler  NaN
# 1005144  actor                                        Himself  NaN
# 1005139  actor                                        Himself  NaN
# 1005154  actor                                        Himself  NaN

# %% [markdown]
# ### Section II - Q4:
#
# (A) What are the top 10 most frequent roles that start with the word "Zombie"?
#
# (B) What are the top 10 most frequent roles that start with the word "Police"?
#
# - Hint: The `startswith()` function might be useful

# %%
# A.
cast[cast.character.str.startswith('Zombie')].character.value_counts().head(10)
# Out:
# Zombie                         6264
# Zombie Horde                    206
# Zombie - Protestor - Victim      78
# Zombie Extra                     70
# Zombie Dancer                    43
# Zombie Girl                      36
# Zombie #1                        36
# Zombie #2                        31
# Zombie Vampire                   25
# Zombie Victim                    22
# Name: character, dtype: int64

# %%
# B.
cast[cast.character.str.startswith('Police')].character.value_counts().head(10)
# Out:
# Policeman              7029
# Police Officer         4808
# Police Inspector        742
# Police Sergeant         674
# Police officer          539
# Police                  456
# Policewoman             415
# Police Chief            410
# Police Captain          387
# Police Commissioner     337
# Name: character, dtype: int64

# %% [markdown]
# ### Section II - Q5: Plot how many roles 'Keanu Reeves' has played in each year of his career.

# %%
kr = cast[cast.name.str.contains('Keanu Reeves')].year.value_counts().sort_index()
ax = kr.plot.bar(figsize=(12,4), color='#649ef5', alpha=0.7)
ax.tick_params(axis='x', colors='white')
plt.grid(visible=True, alpha=0.4, axis='y')
plt.xticks(color='white', rotation=60)
plt.yticks(color='white')
plt.title('# of Roles played by Keanu Reeves per active year', color='white', fontsize=20)
plt.show()

# %% [markdown]
# ### Section II - Q6: Plot the cast positions (n-values) of Keanu Reeve's roles through his career over the years.

# %%
# Create seperate DataFrame for plotting
kr_df = cast[cast.name.str.contains('Keanu Reeves', case=False)][['year', 'n']]
kr_df['n'] = kr_df['n'].fillna(100)

# plot
ax = kr_df.plot.scatter(x='year', y='n', marker='^', s=1000, alpha=0.5, figsize=(10,8));
plt.grid(axis='both', visible=True, alpha=0.3);

ax.tick_params(axis='both', colors='white');
plt.xticks(color='white', rotation=60);
plt.yticks(color='white');
plt.xlabel('Year', color='white', fontsize=15);
plt.ylabel('n   ', color='white', fontsize=25, rotation=0);
plt.title('Keanu Reeves Roles` Importance Over the Years', color='white', fontsize=25);

# %%
# take log of y-axis values to make a more readable graph.

import numpy as np

kr_df['log10n'] = kr_df['n'].map(lambda x: np.log10(x))

# %%
# Plot of log version

ax = kr_df.plot.scatter(x='year', y='log10n', marker='^', s=1000, alpha=0.5, figsize=(10,10));
plt.grid(axis='both', visible=True, alpha=0.3);

ax.tick_params(axis='both', colors='white');
plt.xticks(color='white', rotation=60);
plt.yticks(color='white');
plt.xlabel('Year', color='white', fontsize=15);
plt.ylabel('log10(n)        ', color='white', fontsize=20, rotation=0);
plt.title('Keanu Reeves Roles` Importance Over the Years', color='white', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Keanu Reeves Roles` Importance Over the Years')

# %% [markdown]
# ### Section II - Q7: Plot the number of "Hamlet" films made by each decade

# %%
left_bins = pd.Series(range(1890, 2030, 10))
right_bins = pd.Series(range(1899, 2039, 10))
bin_intervals = pd.IntervalIndex.from_arrays(left_bins, right_bins, closed='both')

out = pd.cut(movies[movies.title.str.contains("Hamlet")].year, bins=bin_intervals, include_lowest=True)
ax = out.value_counts(sort=False).plot.bar(color='#7f71eb', figsize=(12,4))
ax.set_xticklabels([str(i) for i in left_bins], rotation=60, color='white')
ax.yaxis.set_ticks(np.arange(0, 20, 2))
plt.yticks(color = 'white')
plt.grid(visible=True, alpha=0.2)
plt.title('Total Number of Hamlet Films Released per Decade 1890-2020', color='white')
plt.show()

# %% [markdown]
# ### Section II - Q8:
#
# (A) How many leading roles were available to both actors and actresses, in the 1960s (1960-1969)?
#
# (B) How many leading roles were available to both actors and actresses, in the 2000s (2000-2009)?
#
# - Hint: A specific value of n might indicate a leading role

# %% [markdown]
# ### Section II - Q9: List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %% [markdown]
# ### Section II - Q10: List each of the characters that Frank Oz has portrayed at least twice

# %% [markdown]
# # Section III - Advanced Merging, Querying and Visualizations

# %% [markdown]
# ## Make a bar plot with the following conditions
# - Frequency of the number of movies with "Christmas" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %%
christmas = release_dates[(release_dates.title.str.contains('Christmas')) & (release_dates.country == 'USA')]
christmas.date.dt.month.value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# ### Section III - Q1: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Summer" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %% [markdown]
# ### Section III - Q2: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Action" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by week

# %% [markdown]
# ### Section III - Q3: Show all the movies in which Keanu Reeves has played the lead role along with their   release date in the USA sorted by the date of release
# - Hint: You might need to join or merge two datasets!

# %% [markdown]
# ### Section III - Q4: Make a bar plot showing the months in which movies with Keanu Reeves tend to be released in the USA?

# %% [markdown]
# ### Section III - Q5: Make a bar plot showing the years in which movies with Ian McKellen tend to be released in the USA?
